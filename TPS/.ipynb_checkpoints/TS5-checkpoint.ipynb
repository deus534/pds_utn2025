# %%
##############################
##### MODULOS, FUNCIONES #####
##############################
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig
from numpy import random

fs = 1000
N = 1000

def mi_funcion_sen(vmax = 1, dc = 0, ff = 1, ph = 0, nn = N, fss = fs):
    t = nn/fss
    #tt = np.arange(0,t,1/fss)
    tt = np.linspace(0, t, nn, endpoint=False)
    xx = vmax*np.sin(2*np.pi*ff*tt + ph) + dc

    return tt, xx

def cuantizar(Sr, Vf, B):
    q = Vf/(2**(B-1))
    Srq = Sr*1/q
    Sq = np.round(Srq)*q
    
    return Sq, q

# %%
######################
##### PARAMETROS #####
######################
over_sampling = 4
N_os = over_sampling*N
ts = 1/fs
df = fs/N
f = fs/N
f0 = 250
f1 = 600
Vmax = np.sqrt(2)
bins = 10

# Datos del ADC
B = 4           #bits
Vf = 2          #Volts
q = Vf/2**(B-1) #Volts

#ruido digital teorico
kn = 10
pot_ruido = ((q**2)/12) * kn

#(pasos a seguir)
#1. Señal original @ 1 kHz
#2. Oversampling → @ 4 kHz
#3. Filtrado paso bajo (frecuencia de corte ≤ 500 Hz)
#4. Decimación (reducción a 1 kHz)
#5. FFT para analizar y graficar → eje f = 0 a 500 Hz
#########################
##### DISEÑO FILTRO #####
#########################
ftran = 0.1
ripple = 0.5       #db
attenuation = 40   #db
ftype = "butter"
btype = "lowpass"

fc = 1/over_sampling - ftran/2
fst = 1/over_sampling + ftran/2
frecs = [ 0, 0, fc, fst, 1.0 ]
gains = [ 0, -ripple/2, -attenuation/2, -attenuation/2 ]    #db
gains = 10**(np.array(gains)/20)

# paso 1.
orderz, wcutofz = sig.buttord( fc, fst, ripple, attenuation, analog=False)

# paso 2.
numz, denz = sig.iirfilter(orderz, wcutofz, rp=ripple, rs=attenuation, btype=btype, analog=False, ftype=ftype)
sos = sig.iirfilter(orderz, wcutofz, rp=ripple, rs=attenuation, btype=btype, analog=False, ftype=ftype, output='sos')

my_digital_filter = sig.TransferFunction(numz, denz, dt=1/fs)
my_digital_filter_desc = 'butter' + '_ord_' + str(orderz) + '_digital'

# %%
####################
##### ANALISIS #####
####################
#PARTE 1 --- 
tt, s = mi_funcion_sen(vmax=Vmax, ff=f)
n = random.normal(0, np.sqrt(pot_ruido), N)
sr = s + n                      #señal con ruido
srq, _ = cuantizar(sr, Vf, B)   #señal cuantizada
nq = srq - sr                   #error de cuantizacion

#PARTE 2 --- oversampling
n_os = random.normal(0, np.sqrt(pot_ruido), N_os)
def oversampling(freq):
    tt_os, s_os = mi_funcion_sen(vmax=Vmax, ff=freq, nn=N_os, fss=over_sampling*fs)
    sr_os = s_os + n_os
    srq_os, _ = cuantizar(sr_os, Vf, B)
    nq_os = srq_os - sr_os
    return srq_os, nq_os

srq_os, _ = oversampling(f)
srq_os0, _ = oversampling(f0)
srq_os1, _ = oversampling(f1)

#PARTE 3 --- filtrado
def filtrado(srq_os):
    srq_osfilt = sig.sosfilt(sos, srq_os)           #filtrado
    srq_dosfilt = srq_osfilt[::over_sampling]       #decimacion
    srq_dos = srq_os[::over_sampling]               #decimacion sin filtro (posible aliasing)
    return srq_dosfilt, srq_dos
srq_dosfilt, srq_dos = filtrado(srq_os)
srq_dosfilt0, srq_dos0 = filtrado(srq_os0)
srq_dosfilt1, srq_dos1 = filtrado(srq_os1)

#PARTE 4 --- fft
ff = np.arange(0, N, df)
bfrec = ff<=fs/2

ff_os = np.arange(0, N_os, df)
bfrec_os = ff_os <= fs/2

ft_Srq = np.fft.fft(srq)/N

# para frecuencia f=fs/N
ft_Srqos = np.fft.fft(srq_os)/N_os
ft_Srqdos = np.fft.fft(srq_dos)/N
ft_Srqdosfilt = np.fft.fft(srq_dosfilt)/N

# para frecuencia f=250hz
ft_Srqos0 = np.fft.fft(srq_os0)/N_os
ft_Srqdos0 = np.fft.fft(srq_dos0)/N
ft_Srqdosfilt0 = np.fft.fft(srq_dosfilt0)/N

# para frecuencia f=1000hz
ft_Srqos1 = np.fft.fft(srq_os1)/N_os
ft_Srqdos1 = np.fft.fft(srq_dos1)/N
ft_Srqdosfilt1 = np.fft.fft(srq_dosfilt1)/N

# %%
#########################
##### VISUALIZACION #####
#########################

# 1. Filtro
'''
npoints = 1000
w_nyq = 2*np.pi*fs/2
w, mag, _ = my_digital_filter.bode(npoints)

plt.figure(1, figsize=(12,6))
plt.cla()
plt.plot(w/w_nyq, mag, label=my_digital_filter_desc)
plt.title('Plantilla de diseño')
plt.xlabel('Frecuencia normalizada a Nyq [#]')
plt.ylabel('Amplitud [dB]')
plt.grid(which='both', axis='both')
plt.gca().set_xlim([0, 1])
plt.legend()
plt.show()
'''
# 2. Ruido
plt.figure(2, figsize=(12,12))

plt.subplot(3,1,1)
plt.title(f'piso de ruido para {f} Hz')
plt.plot(ff[bfrec], 10*np.log10(2*np.abs(ft_Srqdos[bfrec]**2)))
plt.plot(ff[bfrec], 10*np.log10(2*np.abs(ft_Srqdosfilt[bfrec]**2)))
plt.legend([
        'Decimacion sin filtro',
        'Decimacion con filtro',
    ])

plt.subplot(3,1,2)
plt.title(f'piso de ruido para {f0} Hz')
plt.plot(ff[bfrec], 10*np.log10(2*np.abs(ft_Srqdos0[bfrec]**2)))
plt.plot(ff[bfrec], 10*np.log10(2*np.abs(ft_Srqdosfilt0[bfrec]**2)))
plt.legend([
        'Decimacion sin filtro',
        'Decimacion con filtro',
    ])

plt.subplot(3,1,3)
plt.title(f'piso de ruido para {f1} Hz')
plt.plot(ff[bfrec], 10*np.log10(2*np.abs(ft_Srqdos1[bfrec]**2)))
plt.plot(ff[bfrec], 10*np.log10(2*np.abs(ft_Srqdosfilt1[bfrec]**2)))
plt.legend([
        'Decimacion sin filtro',
        'Decimacion con filtro',
    ])

plt.tight_layout()
plt.show()

# %% [markdown]
# En esta tarea semanal se quiere observar como afecta la aplicacion de un filtro para evitar el aliasing, de manera que se pueda observar como graficamente este problema, asi como tambien como se evita con el filtro pasa bajos.
#
# Teniendo en cuenta las condiciones para la realizacion de esta tarea semanal de un Kn de 1, es decir, que tomamos el ruido digital teorico que depende de la catidad de bits (en nuestro caso 4), y la tension de referencia (2 Volts) se saca el ruido digital teorico como: $pot\_de\_ruido=\frac{q^{2}}{12} * Kn$ siendo Kn ......., tambien tenemos que tener en cuenta que el paso de cuantizacion se saca como $q=\frac{Vref}{2^{B-1}}$
#
# Entonces el procedimiento realizado para poder observar el aliasing, asi como para poder evitarlo fue lo siguiente:
#
# 1. Señal original @ 1 kHz
# 2. Oversampling → @ 4 kHz
# 3. Filtrado paso bajo (frecuencia de corte ≤ 500 Hz)
# 4. Decimación (reducción a 1 kHz)
# 5. FFT para analizar y graficar → eje f = 0 a 500 Hz
#
# Llendo primeramente con el primer paso, nuestro objetivo, o mejor dicho nuestra frecuencia de muestreo original donde queremos trabajar es de 1 KHz, aqui es donde el la tarea TS3 fue donde vimos el piso de ruido analogico, digital donde se muestra como esque dependiendo de nuestras necesidades (si es posible) podemos requerir bajar nuestro piso ya sea analogico o digital.
#
# Bien entonces teniendo estas cuestiones ya un poco entendidas sobre el piso de ruido lo que hicimos fue realizar un oversampling, es decir, tomamos mas muestras por segundo (oversampling=4 -> fs=4000 kHz) entonces volviendo a realizar los mismo pasos que realizamos con la frecuencia orginal (fs = 1kHz) pudimos ver que el piso de ruido bajaba un poco, debido a que el ruido se dispersa mas a lo largo de las frecuencias.
#
# Como ultimo paso lo que hicimos fue realizar un filtrado, especificamente aplicando un filtro pasa bajos con una frecuencia de corte de 500 Hz.
# - ¿por qué 500? porque es nuestra frecuencia de trabajo, la frecuencia original de donde partimos
# - ¿cual es el motivo para aplicar un filtro? al no aplicar un filtro se puede llegar a tener un oversampling cuando se realiza la decimacion.
#
# Una vez aplicado el filtro, lo siguiente que realizamos es la decimacion (tomar una muestra cada N=4 tiempos, por asi decirlo), cuando realizamos la decimacion volvemos a nuestra frecuencia de trabajo, es decir de 0 a 500 Hz, con esto ya tendriamos listo nuestra interpretacion de nuestro enunciado.
#
# Entonces en nuestro analisis seguimos todos estos pasos hasta obtener el ruido digital y luego lo visualizamos en tres disntintos graficos. Y lo que se ve en cada grafico son dos disntintas señales, en la cual una es el ruido digital al realizar el oversampling y luego la decimacion, y por el otro tenemos tambien al ruido digital tambien con oversampling, aplicando un filtro pasa bajos y luego realizando la decimacion, es decir:
# - Señal azul (oversampling -> decimacion)
# - Señal naranja (oversampling -> filtrado (pasa bajos) -> decimacion)
#
# Este analisis lo hize para 3 distintas frecuencias 1 Hz, 250 Hz, 600Hz(posible aliasing).
#
# Bien como entonces en el primer grafico no se puede llegar a notar "tanta diferencia", la frecuencia tanto en el que se aplico el filtro como en el que no, quedan en donde deberia de estar, pero al llegar a los 400 - 500 hz este empieza a bajar ya que el filtro comienza a actuar y se nota como una bajada, esto es debido al filtro.
#
# Entonces en el segundo grafico es mas de lo mismo del primero, frecuencia donde deberia de estar, y lo mismo del filtro al final de la frecuencia 400 - 500 hz.
#
# Lo interesante que se es en el tercer grafico (600 hz) aca se puede notar claramente el tema del aliasing, tenemos una frecuencia de 600 hz que claramente en nuestra banda original de (0-500) no estaba, pero al momento de realizar el oversampling esta es posible, pero cuando nosotros realizamos la decimacion esta aparece como una frecuencia fantasma, por asi decirlo, esto en el caso de que no aplicasemos el filtro.
#
# Si aplicaramos el filtro, como en la señal azul al momento de realizar la decimacion no se llega a observar la frecuencia "fantasma", ya que como aplicamos el filtro pasa bajos todas las frecuencias a partir de 500 quedan casi eliminadas, por lo tanto la frecuencia de 600 hz no existe al momento de realizar la decimacion. Por ende no se llega a observar la frecuencia fantasma.
#
# Conclusiones
#
# Podemos decir que el piso de ruido depende digital depende de la cantidad de bits que tomemos, la tension de referencia, con esto nos da a entedenr que si tuviesemos mas bits en nuestro ADC tendriamos mejor resolucion, lo cual es bueno en sierta parte ya que tambien actua el piso de ruido analogico que de este depende de los componentes que se usa. Entonces habria que tener como un equilibrio entre componentes electronicos y resolucion de nuestro ADC, no limitando a ninguno y teniendo los ruidos analogicos y digital lo mas cerca posible.
#
# Tambien pudimos observar como funciona el aliasing, o mejor dicho como es que lo podemos preveer, en nuestro caso lo que realizamos para mejorar un poco nuestro piso de ruido digital, fue un oversampling y luego realizar la decimacion, asi el ruido digital se distribuye a lo largo de todas las frecuencias, pero como vimos en nuestro analisis y nuestros graficos se observo que si no se hace una correcta decimacion se puede llegar a tener un aliasing.
